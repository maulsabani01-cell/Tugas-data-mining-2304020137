# %% [markdown]
# <a href="https://colab.research.google.com/github/maulsabani01-cell/Tugas-data-mining-2304020137/blob/main/tugas%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %% [markdown]
# to install library 'pandas'

# %%
import pandas as pd

# %% [markdown]
# to import 'pandas' as pd

# %%
from google.colab import drive

# %% [markdown]
# to import data from drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# to connect google drive to colab

# %%
path = '/content/drive/MyDrive/data.csv'

# %% [markdown]
# to save csv file in var 'path'

# %%
df = pd.read_csv(path)

# %%
df.head(10)
# Out:
#                                              Context  \
# 0  Aku sedang melalui beberapa hal dengan perasaa...
# 1  Aku sedang melalui beberapa hal dengan perasaa...
# 2  Aku sedang melalui beberapa hal dengan perasaa...
# 3  Aku sedang melalui beberapa hal dengan perasaa...
# 4  Aku sedang melalui beberapa hal dengan perasaa...
# 5  Aku sedang melalui beberapa hal dengan perasaa...
# 6  Aku sedang melalui beberapa hal dengan perasaa...
# 7  Aku sedang melalui beberapa hal dengan perasaa...
# 8  Aku sedang melalui beberapa hal dengan perasaa...
# 9  Aku sedang melalui beberapa hal dengan perasaa...
#
#                                             Response
# 0  Jika semua orang berpikir Anda tidak berharga,...
# 1  Halo,  dan terima kasih atas pertanyaan Anda d...
# 2  Hal pertama yang saya sarankan adalah mendapat...
# 3  Terapi sangat penting bagi mereka yang merasa ...
# 4  Pertama-tama saya ingin memberi tahu Anda bahw...
# 5  Heck,  pasti,  hun!  Perasaan 'depresi' memili...
# ...

# %% [markdown]
# 10 data awal

# %%
df.tail()
# Out:
#                                                 Context  \
# 5662  Apa saja kesulitan yang bisa ditemui oleh seor...
# 5663  Apa saja kesulitan yang bisa ditemui oleh seor...
# 5664  Apa saja kesulitan yang bisa ditemui oleh seor...
# 5665  Apa saja kesulitan yang bisa ditemui oleh seor...
# 5666  Apa saja kesulitan yang bisa ditemui oleh seor...
#
#                                                Response
# 5662  Meskipun banyak klien memiliki kapasitas untuk...
# 5663  Saya biasanya tidak memberi label klien sebaga...
# 5664  Sial! Heh heh,  dan perbaiki saya jika saya sa...
# 5665  Ya,  seperti beberapa hubungan di luar pekerja...
# 5666  Setiap konselor akan memiliki daftar "kesulita...

# %% [markdown]
# 5 data terakhir

# %%
df.loc[2]
# Out:
# Context     Aku sedang melalui beberapa hal dengan perasaa...
# Response    Hal pertama yang saya sarankan adalah mendapat...
# Name: 2, dtype: object

# %% [markdown]
# untuk mengakses kolom berdasarkan yang kalian inginkan

# %%
df.iloc[1:100]
# Out:
#                                               Context  \
# 1   Aku sedang melalui beberapa hal dengan perasaa...
# 2   Aku sedang melalui beberapa hal dengan perasaa...
# 3   Aku sedang melalui beberapa hal dengan perasaa...
# 4   Aku sedang melalui beberapa hal dengan perasaa...
# 5   Aku sedang melalui beberapa hal dengan perasaa...
# ..                                                ...
# 95  Saya berjuang dengan depresi serta perubahan s...
# 96  Saya berjuang dengan depresi serta perubahan s...
# 97  Saya berjuang dengan depresi serta perubahan s...
# 98  Saya berjuang dengan depresi serta perubahan s...
# 99  Saya melukai diri sendiri,  dan saya berhenti ...
#
#                                              Response
# 1   Halo,  dan terima kasih atas pertanyaan Anda d...
# 2   Hal pertama yang saya sarankan adalah mendapat...
# 3   Terapi sangat penting bagi mereka yang merasa ...
# 4   Pertama-tama saya ingin memberi tahu Anda bahw...
# ...

# %% [markdown]
# memilih baris dari indeks tertentu sampai tertentu

# %%
df['Context'] [1:10]
# Out:
# 1    Aku sedang melalui beberapa hal dengan perasaa...
# 2    Aku sedang melalui beberapa hal dengan perasaa...
# 3    Aku sedang melalui beberapa hal dengan perasaa...
# 4    Aku sedang melalui beberapa hal dengan perasaa...
# 5    Aku sedang melalui beberapa hal dengan perasaa...
# 6    Aku sedang melalui beberapa hal dengan perasaa...
# 7    Aku sedang melalui beberapa hal dengan perasaa...
# 8    Aku sedang melalui beberapa hal dengan perasaa...
# 9    Aku sedang melalui beberapa hal dengan perasaa...
# Name: Context, dtype: object

# %% [markdown]
# menampilkan nilai dari kolom yang kalian inginkan beserta mau berapa
